# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import networkx as nx

import rpy2 as rp
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
import pyreadr

import os
import time
import h5py
# import mmdet
import scanpy
# import ssam
import pickle
import random
# import pyarrow
import dgl
import ast

from tqdm import tqdm

from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score, matthews_corrcoef, mean_squared_error

# from captum.attr import IntegratedGradients
# from captum.attr import LayerConductance
# from captum.attr import NeuronConductance

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.nn.functional as F

# import torch_geometric

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torchvision import transforms, utils

from skimage import io
from skimage import img_as_float
from scipy import ndimage

# from ssam.utils import corr, calc_ctmap, calc_corrmap, flood_fill, calc_kde
from scipy.spatial.distance import cdist

from collections import OrderedDict

from packaging import version
import subprocess

# %% [markdown]
# <h1>Take Matrix

# %%
# read from rds
mat_151507 = pyreadr.read_r('dataset/df_logcount_507.rds')
mat_151672 = pyreadr.read_r('dataset/df_logcount_672.rds')
mat_151673 = pyreadr.read_r('dataset/df_logcount_673.rds')
spat_507 = np.load('dataset/datapoints/row_encoded_507.npy') 
spat_672 = np.load('dataset/datapoints/row_encoded_672.npy') 
spat_673 = np.load('dataset/datapoints/row_encoded_673.npy')

# %%
spat_507.shape
# Out:
# (6101, 1, 11880)

# %%
# dict to dataframe
df_151507 = mat_151507[None]
df_151672 = mat_151672[None]
df_151673 = mat_151673[None]
combined_507_672 = pd.concat([df_151507,df_151672],axis=1)
combined_all = pd.concat([combined_507_672,df_151673],axis=1)

# %%
combined_507_672 = pd.concat([df_151507,df_151672],axis=1)
combined_all = pd.concat([combined_507_672,df_151673],axis=1)

# %%
df_spat507 = pd.DataFrame(spat_507.reshape((spat_507.shape[0],spat_507.shape[-1])))
df_spat672 = pd.DataFrame(spat_672.reshape((spat_672.shape[0],spat_672.shape[-1])))
df_spat673 = pd.DataFrame(spat_673.reshape((spat_673.shape[0],spat_673.shape[-1])))

# %%
df_spat507.shape
# Out:
# (6101, 11880)

# %%
tots = df_151507.shape[1] + df_151672.shape[1] + df_151673.shape[1]
tots
# Out:
# 11880

# %%
df_spat507.columns = combined_all.columns
df_spat672.columns = combined_all.columns
df_spat673.columns = combined_all.columns

# %%
df_spat507
# Out:
#       AAACAACGAATAGTTC-1  AAACAAGTATCTCCCA-1  AAACAATCTACTAGCA-1  \
# 0               0.302599            0.486124            0.452475
# 1               0.401171            0.491480            0.477135
# 2               0.451308            0.493521            0.488914
# 3               0.406347            0.491608            0.478487
# 4               0.188059            0.478778            0.417273
# ...                  ...                 ...                 ...
# 6096            0.350322            0.488697            0.464720
# 6097            0.391376            0.490942            0.474827
# 6098            0.402287            0.491380            0.477423
# 6099            0.447383            0.493380            0.488105
# 6100            0.435589            0.492824            0.485300
#
#       AAACACCAATAACTGC-1  AAACAGCTTTCAGAAG-1  AAACAGGGTCTATATT-1  \
# 0               0.475524            0.297691            0.369552
# 1               0.490033            0.397043            0.437229
# 2               0.496223            0.447624            0.469728
# 3               0.490786            0.402350            0.440623
# 4               0.455091            0.183346            0.281062
# ...                  ...                 ...                 ...
# 6096            0.482666            0.345618            0.402813
# 6097            0.488737            0.387191            0.430768
# 6098            0.490291            0.398230            0.437960
# 6099            0.495851            0.443728            0.467265
# 6100            0.494333            0.431802            0.459643
#
#       AAACAGTGTTCCTGGG-1  AAACATTTCCCGGATT-1  AAAC
# ENSG00000239945  0.484070  0.483107  0.466606
# ...                   ...       ...       ...
# ENSG00000277856  0.476715  0.476189  0.457176
# ENSG00000275063  0.488130  0.487484  0.478688
# ENSG00000271254  0.480849  0.479717  0.463516
# ENSG00000277475  0.485953  0.485485  0.471181
# ENSG00000268674  0.482522  0.481542  0.469002
#
# [33538 rows x 8104 columns]

# %%
embed_all = pd.concat([combined_all,df_spat507], axis=0)
embed_all
# Out:
#                  AAACAACGAATAGTTC-1  AAACAAGTATCTCCCA-1  AAACAATCTACTAGCA-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 6096                       0.350322            0.488697            0.464720
# 6097                       0.391376            0.490942            0.474827
# 6098                       0.402287            0.491380            0.477423
# 6099                       0.447383            0.493380            0.488105
# 6100                       0.435589            0.492824            0.485300
#
#                  AAACACCAATAACTGC-1  AAACAGCTTTCAGAAG-1  AAACAGGGTCTATATT-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 6096                       0.482666            0.345618            0.402813
# 6097                       0.488737            0.387191            0.430768
# 6098                       0.490291            0.398230            0.437960
# 6099                       0.495851            0.443728            0.467265
# 6100                       0.494333            0.431802            0.459643
#
#                  AAACAGTGTTCCTGGG-1  AAACATTTCCCGGATT-1  AAACCACTACACAGAT-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 6096                       0.461607            0.444418            0.408072
# 6097                       0.471635            0.460673            0.433046
# 6098                       0.474284            0.464776            0.439681
# 6099                       0.484784            0.481171            0.466503
# 6100                       0.482037            0.476874            0.459527
#
#                  AAACCCGAACGAAATC-1  ...  TTGTGTATGCCACCAA-1  \
# ENSG00000243485            0.000000  ...            0.000000
# ENSG00000237613            0.000000  ...            0.000000
# ENSG00000186092            0.000000  ...            0.000000
# ENSG00000238009            0.000000  ...            0.000000
# ENSG00000239945            0.000000  ...            0.000000
# ...                             ...  ...                 ...
# 6096                       0.392008  ...            0.389864
# 6097                       0.423140  ...            0.421841
# 6098                       0.431487  ...            0.430325
# 6099                       0.465274  ...            0.464532
# 6100                       0.456586  ...            0.455702
#
#                  TTGTGTTTCCCGAAAG-1  TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 6096                       0.514755            0.506199            0.466397
# 6097                       0.509545            0.504512            0.476507
# 6098                       0.508255            0.504036            0.479390
# 6099                       0.503575            0.502145            0.490867
# 6100                       0.504841            0.502645            0.488027
#
#                  TTGTTGTGTGTCAAGA-1  TTGTTTCACATCCAGG-1  TTGTTTCATTAGTCTA-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 6096                       0.505311            0.420101            0.497707
# 6097                       0.504428            0.443784            0.497475
# 6098                       0.504194            0.449745            0.497340
# 6099                       0.503558            0.474228            0.497411
# 6100                       0.503711            0.467759            0.497289
#
#                  TTGTTTCCATACAACT-1  TTGTTTGTATTACACG-1  TTGTTTGTGTAAATTC-1
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 6096                       0.455874            0.493174            0.402730
# 6097                       0.467883            0.494447            0.431316
# 6098                       0.470904            0.494543            0.438894
# 6099                       0.483183            0.495465            0.469756
# 6100                       0.479989            0.495154            0.461765
#
# [39639 rows x 11880 columns]

# %%
embed_all = pd.concat([embed_all,df_spat672], axis=0)
embed_all
# Out:
#                  AAACAACGAATAGTTC-1  AAACAAGTATCTCCCA-1  AAACAATCTACTAGCA-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 7028                       0.404161            0.491562            0.478128
# 7029                       0.188845            0.479269            0.418851
# 7030                       0.243712            0.483076            0.436724
# 7031                       0.440142            0.493027            0.486370
# 7032                       0.462081            0.494042            0.491422
#
#                  AAACACCAATAACTGC-1  AAACAGCTTTCAGAAG-1  AAACAGGGTCTATATT-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 7028                       0.490509            0.400300            0.439194
# 7029                       0.458041            0.185314            0.282686
# 7030                       0.467960            0.239902            0.326855
# 7031                       0.495012            0.436333            0.462613
# 7032                       0.497615            0.458451            0.476655
#
#                  AAACAGTGTTCCTGGG-1  AAACATTTCCCGGATT-1  AAACCACTACACAGAT-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 7028                       0.474748            0.465467            0.440654
# 7029                       0.414334            0.372791            0.294869
# 7030                       0.432447            0.400208            0.336469
# 7031                       0.483084            0.478606            0.462265
# 7032                       0.488290            0.486574            0.475030
#
#                  AAACCCGAACGAAATC-1  ...  TTGTGTATGCCACCAA-1  \
# ENSG00000243485            0.000000  ...            0.000000
# ENSG00000237613            0.000000  ...            0.000000
# ENSG00000186092            0.000000  ...            0.000000
# ENSG00000238009            0.000000  ...            0.000000
# ENSG00000239945            0.000000  ...            0.000000
# ...                             ...  ...                 ...
# 7028                       0.433003  ...            0.431822
# 7029                       0.257125  ...            0.253490
# 7030                       0.305691  ...            0.302489
# 7031                       0.459849  ...            0.459087
# 7032                       0.475980  ...            0.475617
#
#                  TTGTGTTTCCCGAAAG-1  TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 7028                       0.508224            0.504151            0.480025
# 7029                       0.537101            0.515685            0.415355
# 7030                       0.528213            0.512040            0.434757
# 7031                       0.504211            0.502390            0.489040
# 7032                       0.502018            0.501621            0.494640
#
#                  TTGTTGTGTGTCAAGA-1  TTGTTTCACATCCAGG-1  TTGTTTCATTAGTCTA-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 7028                       0.504182            0.450713            0.497377
# 7029                       0.509514            0.317454            0.498039
# 7030                       0.508013            0.356043            0.497964
# 7031                       0.503583            0.470488            0.497236
# 7032                       0.503279            0.482133            0.497378
#
#                  TTGTTTCCATACAACT-1  TTGTTTGTATTACACG-1  TTGTTTGTGTAAATTC-1
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 7028                       0.471395            0.494766            0.440094
# 7029                       0.401339            0.490616            0.276348
# 7030                       0.422310            0.492047            0.322387
# 7031                       0.481212            0.495240            0.464868
# 7032                       0.487128            0.495761            0.479676
#
# [46672 rows x 11880 columns]

# %%
embed_all = pd.concat([embed_all,df_spat673], axis=0)
embed_all
# Out:
#                  AAACAACGAATAGTTC-1  AAACAAGTATCTCCCA-1  AAACAATCTACTAGCA-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 8099                       0.404028            0.491486            0.477993
# 8100                       0.334474            0.488156            0.461046
# 8101                       0.321003            0.487434            0.457444
# 8102                       0.418018            0.492266            0.481279
# 8103                       0.459199            0.493960            0.490754
#
#                  AAACACCAATAACTGC-1  AAACAGCTTTCAGAAG-1  AAACAGGGTCTATATT-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 8099                       0.490435            0.400040            0.439131
# 8100                       0.481222            0.330221            0.392345
# 8101                       0.479092            0.316786            0.383060
# 8102                       0.492203            0.414148            0.448184
# 8103                       0.497251            0.455521            0.474798
#
#                  AAACAGTGTTCCTGGG-1  AAACATTTCCCGGATT-1  AAACCACTACACAGAT-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 8099                       0.474601            0.465490            0.440856
# 8100                       0.457620            0.438856            0.397683
# 8101                       0.454067            0.433428            0.389594
# 8102                       0.477951            0.470595            0.448956
# 8103                       0.487608            0.485508            0.473306
#
#                  AAACCCGAACGAAATC-1  ...  TTGTGTATGCCACCAA-1  \
# ENSG00000243485            0.000000  ...            0.000000
# ENSG00000237613            0.000000  ...            0.000000
# ENSG00000186092            0.000000  ...            0.000000
# ENSG00000238009            0.000000  ...            0.000000
# ENSG00000239945            0.000000  ...            0.000000
# ...                             ...  ...                 ...
# 8099                       0.432719  ...            0.431650
# 8100                       0.379239  ...            0.377429
# 8101                       0.368984  ...            0.366499
# 8102                       0.443375  ...            0.442292
# 8103                       0.473864  ...            0.473470
#
#                  TTGTGTTTCCCGAAAG-1  TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  \
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
#
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 8099                       0.504232            0.450862            0.497344
# 8100                       0.505566            0.411650            0.497606
# 8101                       0.505722            0.404450            0.497945
# 8102                       0.504028            0.458276            0.497362
# 8103                       0.503325            0.480585            0.497384
#
#                  TTGTTTCCATACAACT-1  TTGTTTGTATTACACG-1  TTGTTTGTGTAAATTC-1
# ENSG00000243485            0.000000            0.000000            0.000000
# ENSG00000237613            0.000000            0.000000            0.000000
# ENSG00000186092            0.000000            0.000000            0.000000
# ENSG00000238009            0.000000            0.000000            0.000000
# ENSG00000239945            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# 8099                       0.471361            0.494474            0.440360
# 8100                       0.451269            0.493267            0.390928
# 8101                       0.446825            0.492925            0.381031
# 8102                       0.475161            0.494960            0.449647
# 8103                       0.486328            0.495686            0.477695
#
# [54776 rows x 11880 columns]

# %%
# embed_all.to_csv('dataset/datapoints/embed_all.csv',index = False)

# Save DataFrame to CSV with progress bar
embed_all.to_csv('dataset/datapoints/embed_all.csv',index = False, chunksize=1000,progress_bar=True)
# Out:
# Saving DataFrame: 100%|██████████████████████████████████████████████████████████████████████| 54776/54776 [04:54<00:00, 186.19it/s]
# True
# Saving DataFrame: 100%|██████████████████████████████████████████████████████████████████████| 54776/54776 [05:09<00:00, 186.19it/s]

# %%
import sys
a = sys.getsizeof(df_spat507)/(1024 ** 2)
b = sys.getsizeof(df_151507)/(1024 ** 2)
c = sys.getsizeof(df_spat672)/(1024 ** 2)
d = sys.getsizeof(df_151672)/(1024 ** 2)
e = sys.getsizeof(df_spat673)/(1024 ** 2)
f = sys.getsizeof(df_151673)/(1024 ** 2)
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)

print(a+b+c+d+e+f)
print(sys.getsizeof(embed_all)/(1024 ** 2))
# Out:
# 552.9777374267578
# 1083.6290893554688
# 637.4516143798828
# 1029.6395416259766
# 734.5240631103516
# 933.4306793212891
# 4971.652725219727
# 4967.775676727295

# %%
# embed_507.to_csv('datapoints/embedded_507.csv', index=False)
pyreadr.write_rds('datapoints/embed_507.rds', embed_507, compress='gzip')

# %%
pyreadr.write_rds('datapoints/embed_672.rds', embed_672, compress='gzip')

# %%
pyreadr.write_rds('datapoints/embed_673.rds', embed_673, compress='gzip')

# %%
# filters gene with 0 value throughout assay matrix
summ = df_151507.sum(axis=1)
filtered_151507 = df_151507.loc[summ>0]
summ = df_151672.sum(axis=1)
filtered_151672 = df_151672.loc[summ>0]
summ = df_151673.sum(axis=1)
filtered_151673 = df_151673.loc[summ>0]
summ = combined_all.sum(axis=1)
filtered_all = combined_all.loc[summ>0]

# this results in a non-uniform rows, should concate first before filters

# %%
# selected gene after filtering non-zero across all samples
df = pd.DataFrame(filtered_all.index.tolist())
selected_gene = df[0].tolist()

# %%
len(selected_gene)
# Out:
# 23465

# %%
df_151673.loc[selected_gene]
# Out:
#                  AAACAAGTATCTCCCA-1  AAACAATCTACTAGCA-1  AAACACCAATAACTGC-1  \
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
#                  AAACAGAGCGACTCCT-1  AAACAGCTTTCAGAAG-1  AAACAGGGTCTATATT-1  \
# rownames
# ENSG00000243485                 0.0            0.000000                 0.0
# ENSG00000238009                 0.0            0.000000                 0.0
# ENSG00000229905                 0.0            0.000000                 0.0
# ENSG00000237491                 0.0            0.000000                 0.0
# ENSG00000177757                 0.0            0.000000                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0            0.804885                 0.0
# ENSG00000277196                 0.0            0.000000                 0.0
# ENSG00000278384                 0.0            0.000000                 0.0
# ENSG00000271254                 0.0            0.000000                 0.0
# ENSG00000268674                 0.0            0.000000                 0.0
#
#                  AAACAGTGTTCCTGGG-1  AAACATTTCCCGGATT-1  AAACCCGAACGAAATC-1  \
# rownames
# ENSG00000243485                 0.0            0.000000            0.000000
# ENSG00000238009                 0.0            0.000000            0.000000
# ENSG00000229905                 0.0            0.000000            0.000000
# ENSG00000237491                 0.0            0.000000            0.000000
# ENSG00000177757                 0.0            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0            0.481892            0.000000
# ENSG00000277196                 0.0            0.000000            0.328571
# ENSG00000278384                 0.0            0.000000            0.000000
# ENSG00000271254                 0.0            0.000000            0.000000
# ENSG00000268674                 0.0            0.000000            0.000000
#
#                  AAACCGGGTAGGTACC-1  ...  TTGTGTATGCCACCAA-1  \
# rownames                             ...
# ENSG00000243485                 0.0  ...                 0.0
# ENSG00000238009                 0.0  ...                 0.0
# ENSG00000229905                 0.0  ...                 0.0
# ENSG00000237491                 0.0  ...                 0.0
# ENSG00000177757                 0.0  ...                 0.0
# ...                             ...  ...                 ...
# ENSG00000278817                 0.0  ...                 0.0
# ENSG00000277196                 0.0  ...                 0.0
# ENSG00000278384                 0.0  ...                 0.0
# ENSG00000271254                 0.0  ...                 0.0
# ENSG00000268674                 0.0  ...                 0.0
#
#                  TTGTGTTTCCCGAAAG-1  TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  \
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
#                  TTGTTGTGTGTCAAGA-1  TTGTTTCACATCCAGG-1  TTGTTTCATTAGTCTA-1  \
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
#                  TTGTTTCCATACAACT-1  TTGTTTGTATTACACG-1  TTGTTTGTGTAAATTC-1
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
# [23465 rows x 3639 columns]

# %%
df['coord_list'] = pd.Series(dtype=str)
df['coord_count'] = pd.Series(dtype=int)

# %%
df_507 = df.copy()
df_673 = df.copy()
df_672 = df.copy()

# %%
df
# Out:
#                      0 coord_list  coord_count
# 0      ENSG00000243485        NaN          NaN
# 1      ENSG00000238009        NaN          NaN
# 2      ENSG00000229905        NaN          NaN
# 3      ENSG00000237491        NaN          NaN
# 4      ENSG00000177757        NaN          NaN
# ...                ...        ...          ...
# 23460  ENSG00000278817        NaN          NaN
# 23461  ENSG00000277196        NaN          NaN
# 23462  ENSG00000278384        NaN          NaN
# 23463  ENSG00000271254        NaN          NaN
# 23464  ENSG00000268674        NaN          NaN
#
# [23465 rows x 3 columns]

# %% [markdown]
# <h1>Preprocess

# %%
# assay into multiple instances

# read each spots coordinates
coord507 = pyreadr.read_r('spatialLIBD/r_lib/coord_151507.rds')
coord672 = pyreadr.read_r('spatialLIBD/r_lib/coord_151672.rds')
coord673 = pyreadr.read_r('spatialLIBD/r_lib/coord_151673.rds')

# coordinates in respect to gene count values

# output should be matrix of gene distribution for each gene

# %%
coord507 = coord507[None]
coord672 = coord672[None]
coord673 = coord673[None]

# %%
coord507
# Out:
#                     pxl_col_in_fullres  pxl_row_in_fullres
# AAACAACGAATAGTTC-1              3276.0              2514.0
# AAACAAGTATCTCCCA-1              9178.0              8520.0
# AAACAATCTACTAGCA-1              5133.0              2878.0
# AAACACCAATAACTGC-1              3462.0              9581.0
# AAACAGCTTTCAGAAG-1              2779.0              7663.0
# ...                                ...                 ...
# TTGTTGTGTGTCAAGA-1              7464.0              6239.0
# TTGTTTCACATCCAGG-1              5045.0              9466.0
# TTGTTTCATTAGTCTA-1              4218.0              9703.0
# TTGTTTCCATACAACT-1              4017.0              7906.0
# TTGTTTGTGTAAATTC-1              5683.0              3359.0
#
# [4226 rows x 2 columns]

# %%
coord672
# Out:
#                     pxl_col_in_fullres  pxl_row_in_fullres
# AAACAAGTATCTCCCA-1             10215.0              8703.0
# AAACACCAATAACTGC-1              4499.0              9767.0
# AAACAGAGCGACTCCT-1              9675.0              4390.0
# AAACAGCTTTCAGAAG-1              3816.0              7849.0
# AAACAGGGTCTATATT-1              4090.0              8329.0
# ...                                ...                 ...
# TTGTTGTGTGTCAAGA-1              8500.0              6423.0
# TTGTTTCACATCCAGG-1              6083.0              9651.0
# TTGTTTCATTAGTCTA-1              5256.0              9889.0
# TTGTTTCCATACAACT-1              5054.0              8092.0
# TTGTTTGTGTAAATTC-1              6717.0              3544.0
#
# [4015 rows x 2 columns]

# %%
coord673
# Out:
#                     pxl_col_in_fullres  pxl_row_in_fullres
# AAACAAGTATCTCCCA-1              9791.0              8468.0
# AAACAATCTACTAGCA-1              5769.0              2807.0
# AAACACCAATAACTGC-1              4068.0              9505.0
# AAACAGAGCGACTCCT-1              9271.0              4151.0
# AAACAGCTTTCAGAAG-1              3393.0              7583.0
# ...                                ...                 ...
# TTGTTTCACATCCAGG-1              5653.0              9396.0
# TTGTTTCATTAGTCTA-1              4825.0              9630.0
# TTGTTTCCATACAACT-1              4631.0              7831.0
# TTGTTTGTATTACACG-1              5571.0             11193.0
# TTGTTTGTGTAAATTC-1              6317.0              3291.0
#
# [3639 rows x 2 columns]

# %% [markdown]
# <h5> get coordinate list from assay

# %%
# get selected gene from individual sample
select_507 = df_151507.loc[selected_gene]
select_507
# Out:
#                  AAACAACGAATAGTTC-1  AAACAAGTATCTCCCA-1  AAACAATCTACTAGCA-1  \
# rownames
# ENSG00000243485                 0.0            0.000000                 0.0
# ENSG00000238009                 0.0            0.000000                 0.0
# ENSG00000229905                 0.0            0.000000                 0.0
# ENSG00000237491                 0.0            0.000000                 0.0
# ENSG00000177757                 0.0            0.000000                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0            0.841739                 0.0
# ENSG00000277196                 0.0            0.000000                 0.0
# ENSG00000278384                 0.0            0.000000                 0.0
# ENSG00000271254                 0.0            0.000000                 0.0
# ENSG00000268674                 0.0            0.000000                 0.0
#
#                  AAACACCAATAACTGC-1  AAACAGCTTTCAGAAG-1  AAACAGGGTCTATATT-1  \
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
#                  AAACAGTGTTCCTGGG-1  AAACATTTCCCGGATT-1  AAACCACTACACAGAT-1  \
# rownames
# ENSG00000243485            0.000000                 0.0            0.000000
# ENSG00000238009            0.000000                 0.0            0.000000
# ENSG00000229905            0.000000                 0.0            0.000000
# ENSG00000237491            0.000000                 0.0            0.000000
# ENSG00000177757            0.000000                 0.0            0.000000
# ...                             ...                 ...                 ...
# ENSG00000278817            1.382027                 0.0            0.000000
# ENSG00000277196            0.000000                 0.0            0.593077
# ENSG00000278384            0.000000                 0.0            0.000000
# ENSG00000271254            0.000000                 0.0            0.000000
# ENSG00000268674            0.000000                 0.0            0.000000
#
#                  AAACCCGAACGAAATC-1  ...  TTGTGTATGCCACCAA-1  \
# rownames                             ...
# ENSG00000243485                 0.0  ...                 0.0
# ENSG00000238009                 0.0  ...                 0.0
# ENSG00000229905                 0.0  ...                 0.0
# ENSG00000237491                 0.0  ...                 0.0
# ENSG00000177757                 0.0  ...                 0.0
# ...                             ...  ...                 ...
# ENSG00000278817                 0.0  ...                 0.0
# ENSG00000277196                 0.0  ...                 0.0
# ENSG00000278384                 0.0  ...                 0.0
# ENSG00000271254                 0.0  ...                 0.0
# ENSG00000268674                 0.0  ...                 0.0
#
#                  TTGTGTTTCCCGAAAG-1  TTGTTAGCAAATTCGA-1  TTGTTCAGTGTGCTAC-1  \
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
#                  TTGTTCTAGATACGCT-1  TTGTTGTGTGTCAAGA-1  TTGTTTCACATCCAGG-1  \
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
#                  TTGTTTCATTAGTCTA-1  TTGTTTCCATACAACT-1  TTGTTTGTGTAAATTC-1
# rownames
# ENSG00000243485                 0.0                 0.0                 0.0
# ENSG00000238009                 0.0                 0.0                 0.0
# ENSG00000229905                 0.0                 0.0                 0.0
# ENSG00000237491                 0.0                 0.0                 0.0
# ENSG00000177757                 0.0                 0.0                 0.0
# ...                             ...                 ...                 ...
# ENSG00000278817                 0.0                 0.0                 0.0
# ENSG00000277196                 0.0                 0.0                 0.0
# ENSG00000278384                 0.0                 0.0                 0.0
# ENSG00000271254                 0.0                 0.0                 0.0
# ENSG00000268674                 0.0                 0.0                 0.0
#
# [23465 rows x 4226 columns]

# %%
# fiters rows from assays, get coordinate list and coordinate count
for i in tqdm(range(len(filtered_all))):   
    a = select_507.iloc[i]
    df_507.loc[i, 'coord_list'] = str(a[a>0].index.tolist())
    df_507.loc[i, 'coord_count'] = len(a[a>0].index.tolist())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23465/23465 [00:39<00:00, 597.50it/s]

# %%
# Number of gene that have non-zero values, from the initial 33538. should be used as the final shape
df
# Out:
#                      0 coord_list  coord_count
# 0      ENSG00000243485        NaN          NaN
# 1      ENSG00000238009        NaN          NaN
# 2      ENSG00000229905        NaN          NaN
# 3      ENSG00000237491        NaN          NaN
# 4      ENSG00000177757        NaN          NaN
# ...                ...        ...          ...
# 23460  ENSG00000278817        NaN          NaN
# 23461  ENSG00000277196        NaN          NaN
# 23462  ENSG00000278384        NaN          NaN
# 23463  ENSG00000271254        NaN          NaN
# 23464  ENSG00000268674        NaN          NaN
#
# [23465 rows x 3 columns]

# %%
df_672
# Out:
#                      0                                         coord_list  \
# 0      ENSG00000243485                                                 []
# 1      ENSG00000238009  ['ACCCTATAGGACTGAG-1', 'ATCGCCAGTCAACATT-1', '...
# 2      ENSG00000229905                             ['GCTAAACCTGAGGTGA-1']
# 3      ENSG00000237491  ['AACCAAGACTTCTCTG-1', 'AACCCTACTGTCAATA-1', '...
# 4      ENSG00000177757                                                 []
# ...                ...                                                ...
# 23460  ENSG00000278817  ['AAACCGGAAATGTTAA-1', 'AAACGACAGTCTTGCC-1', '...
# 23461  ENSG00000277196  ['AAATTGGTGAGAAGCA-1', 'AAATTTGCGGGTGTGG-1', '...
# 23462  ENSG00000278384       ['CCCAACATACGTCGCG-1', 'TATTAACACCAAAGCA-1']
# 23463  ENSG00000271254  ['AATTGAACGCTCTGGT-1', 'AGACCATGGGATACAA-1', '...
# 23464  ENSG00000268674                                                 []
#
#        coord_count
# 0              0.0
# 1             13.0
# 2              1.0
# 3             84.0
# 4              0.0
# ...            ...
# 23460        620.0
# 23461         65.0
# 23462          2.0
# 23463          7.0
# 23464          0.0
#
# [23465 rows x 3 columns]

# %%
df_507
# Out:
#                      0                                         coord_list  \
# 0      ENSG00000243485                             ['TTGCCAAGCAGAACCC-1']
# 1      ENSG00000238009  ['CGCAATTAGGGTAATA-1', 'CTGCAAGCACGTTCCG-1', '...
# 2      ENSG00000229905                                                 []
# 3      ENSG00000237491  ['AAAGACCCAAGTCGCG-1', 'AAAGTAGCATTGCTCA-1', '...
# 4      ENSG00000177757                             ['GGAGGGTCAAGTAAGA-1']
# ...                ...                                                ...
# 23460  ENSG00000278817  ['AAACAAGTATCTCCCA-1', 'AAACAGTGTTCCTGGG-1', '...
# 23461  ENSG00000277196  ['AAACCACTACACAGAT-1', 'AACTGGGTTCGAGCCG-1', '...
# 23462  ENSG00000278384       ['AGTCACTCCGCCTCAT-1', 'ATACGGTGAAGATGCA-1']
# 23463  ENSG00000271254  ['AGAAGGTTGCCGAATT-1', 'AGACTGTTACCGGGTC-1', '...
# 23464  ENSG00000268674                                                 []
#
#        coord_count
# 0              1.0
# 1              6.0
# 2              0.0
# 3             57.0
# 4              1.0
# ...            ...
# 23460        530.0
# 23461         44.0
# 23462          2.0
# 23463          6.0
# 23464          0.0
#
# [23465 rows x 3 columns]

# %% [markdown]
# <h3>Filter genes with minimum points of coordinates (currently 250)

# %%
# filter genes with minimum points of coordinates
df_507_min = df_507.loc[:][df_507.loc[:]['coord_count']>250]

# %%
df_672_min
# Out:
#                      0                                         coord_list  \
# 11     ENSG00000188976  ['AAACAGAGCGACTCCT-1', 'AAACAGGGTCTATATT-1', '...
# 16     ENSG00000188290  ['AAACAAGTATCTCCCA-1', 'AAACACCAATAACTGC-1', '...
# 17     ENSG00000187608  ['AAACAAGTATCTCCCA-1', 'AAACCGGGTAGGTACC-1', '...
# 18     ENSG00000188157  ['AAACAAGTATCTCCCA-1', 'AAACCCGAACGAAATC-1', '...
# 26     ENSG00000078808  ['AAACAGAGCGACTCCT-1', 'AAACCGTTCGTCCAGG-1', '...
# ...                ...                                                ...
# 23449  ENSG00000198886  ['AAACAAGTATCTCCCA-1', 'AAACACCAATAACTGC-1', '...
# 23450  ENSG00000198786  ['AAACAAGTATCTCCCA-1', 'AAACACCAATAACTGC-1', '...
# 23451  ENSG00000198695  ['AAACCGGAAATGTTAA-1', 'AAACCGGGTAGGTACC-1', '...
# 23452  ENSG00000198727  ['AAACAAGTATCTCCCA-1', 'AAACACCAATAACTGC-1', '...
# 23460  ENSG00000278817  ['AAACCGGAAATGTTAA-1', 'AAACGACAGTCTTGCC-1', '...
#
#        coord_count
# 11           551.0
# 16           781.0
# 17          1058.0
# 18           647.0
# 26           953.0
# ...            ...
# 23449       4015.0
# 23450       3877.0
# 23451       1690.0
# 23452       4015.0
# 23460        620.0
#
# [7033 rows x 3 columns]

# %%
df_507_min
# Out:
#                      0                                         coord_list  \
# 11     ENSG00000188976  ['AAACCTAAGCAGCCGG-1', 'AAACGAAGAACATACC-1', '...
# 16     ENSG00000188290  ['AAACATTTCCCGGATT-1', 'AAACGGGCGTACGGGT-1', '...
# 17     ENSG00000187608  ['AAACAACGAATAGTTC-1', 'AAACAAGTATCTCCCA-1', '...
# 18     ENSG00000188157  ['AAACATTTCCCGGATT-1', 'AAACGGGCGTACGGGT-1', '...
# 26     ENSG00000078808  ['AAACAGGGTCTATATT-1', 'AAACCACTACACAGAT-1', '...
# ...                ...                                                ...
# 23449  ENSG00000198886  ['AAACAACGAATAGTTC-1', 'AAACAAGTATCTCCCA-1', '...
# 23450  ENSG00000198786  ['AAACAAGTATCTCCCA-1', 'AAACAATCTACTAGCA-1', '...
# 23451  ENSG00000198695  ['AAACACCAATAACTGC-1', 'AAACAGGGTCTATATT-1', '...
# 23452  ENSG00000198727  ['AAACAACGAATAGTTC-1', 'AAACAAGTATCTCCCA-1', '...
# 23460  ENSG00000278817  ['AAACAAGTATCTCCCA-1', 'AAACAGTGTTCCTGGG-1', '...
#
#        coord_count
# 11           435.0
# 16           709.0
# 17          1064.0
# 18           534.0
# 26           756.0
# ...            ...
# 23449       4226.0
# 23450       4149.0
# 23451       1242.0
# 23452       4224.0
# 23460        530.0
#
# [6101 rows x 3 columns]

# %%
df_507_res = df_507_min.reset_index()
df_507_res
# Out:
#       index                0  \
# 0        11  ENSG00000188976
# 1        16  ENSG00000188290
# 2        17  ENSG00000187608
# 3        18  ENSG00000188157
# 4        26  ENSG00000078808
# ...     ...              ...
# 6096  23449  ENSG00000198886
# 6097  23450  ENSG00000198786
# 6098  23451  ENSG00000198695
# 6099  23452  ENSG00000198727
# 6100  23460  ENSG00000278817
#
#                                              coord_list  coord_count
# 0     ['AAACCTAAGCAGCCGG-1', 'AAACGAAGAACATACC-1', '...        435.0
# 1     ['AAACATTTCCCGGATT-1', 'AAACGGGCGTACGGGT-1', '...        709.0
# 2     ['AAACAACGAATAGTTC-1', 'AAACAAGTATCTCCCA-1', '...       1064.0
# 3     ['AAACATTTCCCGGATT-1', 'AAACGGGCGTACGGGT-1', '...        534.0
# 4     ['AAACAGGGTCTATATT-1', 'AAACCACTACACAGAT-1', '...        756.0
# ...                                                 ...          ...
# 6096  ['AAACAACGAATAGTTC-1', 'AAACAAGTATCTCCCA-1', '...       4226.0
# 6097  ['AAACAAGTATCTCCCA-1', 'AAACAATCTACTAGCA-1', '...       4149.0
# 6098  ['AAACACCAATAACTGC-1', 'AAACAGGGTCTATATT-1', '...       1242.0
# 6099  ['AAACAACGAATAGTTC-1', 'AAACAAGTATCTCCCA-1', '...       4224.0
# 6100  ['AAACAAGTATCTCCCA-1', 'AAACAGTGTTCCTGGG-1', '...        530.0
#
# [6101 rows x 4 columns]

# %%
max_row_indices = df_507_res['coord_count'].idxmax()
max_row_indices
# Out:
# 6089

# %%
df_res.loc[max_row_indices]
# Out:
# index                                                      23440
# 0                                                ENSG00000198888
# coord_list     ['AAACAAGTATCTCCCA-1', 'AAACAATCTACTAGCA-1', '...
# coord_count                                               3639.0
# Name: 8090, dtype: object

# %%
df_672_res.loc[0,0]
# Out:
# 'ENSG00000188976'

# %% [markdown]
# <h5> from coordinate list into 2D matrix

# %%
# for i in range(len(df_res)):

directory = 'datapoints/151507/'

for i in range(len(df_507_res)):

    # get coord_list from dataframe as string back to list
    my_list = ast.literal_eval(df_507_res.loc[i,'coord_list'])

    # table for converting coordinate list into actual pixel coordinates
    ext_coord = coord507.loc[my_list]

    # points = coord673.values.tolist()
    # sites = coord673.index.tolist()
    points = ext_coord.values.tolist()
    sites = ext_coord.index.tolist()
    
    x, y = zip(*points)
    
    # Convert into 2D matrix
    x_resolution = 200
    y_resolution = 250

    x_min = min(x)
    x_max = max(x)
    x_ptp = x_max - x_min

    y_min = min(y)
    y_max = max(y)
    y_ptp = y_max - y_min

    img = np.zeros((y_resolution+20, x_resolution+20), dtype=bool)

    for k, l in points:
        x_pxl = (k - x_min) / x_ptp * x_resolution
        y_pxl = (l - y_min) / y_ptp * y_resolution
        img[int(y_pxl+10), int(x_pxl+10)] = 1
    
    np.save(directory+df_507_res.loc[i,0]+'.npy',img)

# %%
# for i in range(len(points)):
#     for j in range(len(points[i])):
#         points[i][j] = points[i][j] * 0.02
# points[0:4]

# %%
# x, y = zip(*points)

# %%
# print(points[0],x[0],y[0])
# Out:
# [9791.0, 8468.0] 9791.0 8468.0

# %%
# for i, filename in enumerate(os.listdir('datapoints/151673')):
#     print(filename)
directory = 'datapoints/151507'
len(os.listdir(directory))
# Out:
# 6101

# %%
filenames = os.listdir(directory)
filenames[:3]
# Out:
# ['ENSG00000137168.npy', 'ENSG00000139168.npy', 'ENSG00000072518.npy']

# %%
plt.figure(figsize=(8,10))

fig, ax = plt.subplots(3,1,figsize=(12,36))

for i, filename in enumerate(filenames[:3]) :
    if filename.endswith('.npy') and os.path.isfile(os.path.join(directory, filename)):
        new_test = np.load(directory+'/'+filename)   
        ax[i].imshow(new_test, cmap='viridis',origin='lower')

plt.show()

# %%
# 2D matrix are formed, but seems to be too sparse to be learned need to rescale
plt.figure(figsize=(8,10))

fig, ax = plt.subplots(figsize=(8,10))
ax.imshow(img, cmap='viridis',origin='lower')
plt.savefig('plot.png')
plt.show()

# %%
# 2D matrix are formed, but seems to be too sparse to be learned need to rescale
plt.figure(figsize=(8,10))

fig, ax = plt.subplots(figsize=(8,10))
ax.imshow(img, cmap='viridis',origin='lower')
# plt.savefig('plot.png')
plt.show()

# %%
plt.figure(figsize=(8,10))
plt.scatter(x,y,s=5,c='b')
plt.show()

# %%
len(sites)
# Out:
# 3639

# %% [markdown]
# <h1>Feed to NN

# %%
# NN take matrix of gene distribution

# make into tensor

# run NN model

# output should be decoder part of hidden features

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"
train_root_path = '/home/Spatial_transcriptomic/VERIFY/train' 
test_root_path = '/home/Spatial_transcriptomic/VERIFY/test'
batch_size = 300
epochs = 200
learning_rate = 1e-3
im_size = size_10
# torch.manual_seed(42)

# %%
instance_X_train, instance_X_test = train_test_split(instance_imgs_10, test_size=0.20, random_state=42,shuffle=True) 


train_dataset = TumorDatasetTrain(instance=instance_X_train, root_dir=train_root_path,
                                transform=transforms.Compose([ToTensor()]))
test_dataset = TumorDatasetTest(instance=instance_X_test, root_dir=test_root_path, 
                                transform=transforms.Compose([ToTensor()]))
all_dataset = TumorDatasetAll(instance=instance_imgs_10, root_dir=train_root_path,
                                transform=transforms.Compose([ToTensor()]))

dataloader_all = DataLoader(all_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
dataloader_train = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
dataloader_test = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, num_workers=1)

running_loss = []
running_vloss = []

# %%
model_path1 = "/home/Spatial_transcriptomic/VERIFY/lab06_AE_weight_decay.pth"
save = False
pret = False

# %%
#  use gpu if available
start_time1 = time.time()

device = torch.device("cuda")

# create a model from `AE` autoencoder class
# load it to the specified device, either gpu or cpu
# model = ConvAutoencoder().to(device)
model = AE(input_shape=im_size*im_size*33).to(device)
model.double()

# create an optimizer object
# Adam optimizer with learning rate 1e-3
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# mean-squared error loss
criterion = nn.MSELoss()
running_loss = []
running_vloss = []

#     Auto Encoder Training
print('Training AE')
if (not os.path.exists(model_path1) or not pret):
    for epoch in range(epochs):
        start_time = time.time()
        loss = 0
        vloss = 0
        model.train()
        for batch_ndx, batch_features in enumerate(dataloader_train):
            # reshape mini-batch data to [N, 784] matrix
            # load it to the active device
    #             batch_features = Variable(batch_features['image']).to(device)
    #             batch_features = batch_features.type(torch.cuda.FloatTensor)
            images = Variable(batch_features['image']).view(-1,im_size*im_size*33).to(device)
    #             images = images.type(torch.cuda.FloatTensor)
            # reset the gradients back to zero
            # PyTorch accumulates gradients on subsequent backward passes
            optimizer.zero_grad()

            # compute reconstructions
            outputs, coded = model(images)
#             print('size', outputs.size(), coded.size())
    #             encoder_only_nosig = model.encoder(images)
    #             encoder_only = torch.sigmoid(model.encoder(images))
            # compute training reconstruction loss
            train_loss = criterion(outputs, images)

            # compute accumulated gradients
            train_loss.backward()

            # perform parameter update based on current gradients
            optimizer.step()
            # add the mini-batch training loss to epoch loss
            loss += train_loss.item()

        # compute the epoch training loss
        loss = loss / len(dataloader_train)
        running_loss.append(loss)
        # display the epoch training loss
        #if(epoch % 5 == 0):
    #       ------------------------------------------------------------------------  
        model.eval()
        with torch.no_grad():
            for batch_ndx, batch_features in enumerate(dataloader_test):
                # reshape mini-batch data to [N, 784] matrix
                # load it to the active device
    #             batch_features = Variable(batch_features['image']).to(device)
    #             batch_features = batch_features.type(torch.cuda.FloatTensor)
                images = Variable(batch_features['image']).view(-1,im_size*im_size*33).to(device)
    #                 images = images.type(torch.cuda.FloatTensor)
                # reset the gradients back to zero
                # PyTorch accumulates gradients on subsequent backward passes
                optimizer.zero_grad()

                # compute reconstructions
                outputs, coded = model(images)
    #             encoder_only_nosig = model.encoder(images)
    #             encoder_only = torch.sigmoid(model.encoder(images))
                # compute training reconstruction loss
                valid_loss = criterion(outputs, images)

                # perform parameter update based on current gradients
    #                 optimizer.step()
                # add the mini-batch training loss to epoch loss
                vloss += valid_loss.item()

            # compute the epoch training loss
            vloss = vloss / len(dataloader_test)
            running_vloss.append(vloss)

    #     -----------------------------------------------------------------------------
        current_time = time.time()
        elapsed_time = current_time - start_time
        print("epoch : {}/{}, recon loss = {:.8f}, valid loss = {:.8f}, time = {:.2f}s".format(epoch + 1, epochs, loss, vloss, elapsed_time))


        if (epoch > 3) and (abs(running_vloss[epoch] - running_vloss[epoch-1]) <= 0.0001) and (abs(running_vloss[epoch - 1] - running_vloss[epoch - 2]) <= 0.0001):
            print('satisfied early stop')
            break
    if save:
        torch.save(model.state_dict(), model_path1)

# %%
coord_list = [[1.2, 3.4], [2.3, 4.5], [3.4, 5.6], [4.5, 6.7]]

# convert the list to a PyTorch tensor
coords = torch.tensor(coord_list)

# reshape the tensor to the required input shape (batch size, number of channels, height, width)
coords = coords.view(1, 1, -1, 2)

# %%
coords
# Out:
# tensor([[[[1.2000, 3.4000],
#           [2.3000, 4.5000],
#           [3.4000, 5.6000],
#           [4.5000, 6.7000]]]])

# %% [markdown]
# <h1>Run BEER

# %%
# get decoder hidden feature and concatenate with assays

# final matrix includes ~100 extra features of spatial embeddings treated as spots

# BEER should results in a Umap plot, Correlation plot, and no-Batch effect umap
